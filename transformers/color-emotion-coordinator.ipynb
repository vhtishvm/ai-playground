# %%
import numpy as np
import random

# %%
#Raw data
senA = "The rose is red"
senB = "The signal is red"

wordsA = senA.split()
print(wordsA)

wordsB = senB.split()
print(wordsB)
# Out:
# ['The', 'rose', 'is', 'red']
# ['The', 'signal', 'is', 'red']

# %%
#Assigning a single token for each word
#random.seed(42)
encodingA = {}

random_number = random.randint(1,10)
for word in wordsA:
    if word not in encodingA:
        encodingA[random_number] = word
        
encodingA
# Out:
# {4: 'red'}

# %%
#Assigning a single token for each word
random.seed(42)
encodingA = {}

random_number = random.randint(1,10)
for word in wordsA:
    if word not in encodingA:
        encodingA[counter] = word
        counter += 1
encodingA
# Out:
# {17: 'The', 18: 'rose', 19: 'is', 20: 'red'}
