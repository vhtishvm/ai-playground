# %%
import numpy as np

# %%
arr = np.array([[1,2,3,4,5],
                [2,3,4,5,6],
                [12,23,34,45,34]])
print(arr.shape)
print(len(arr))
print(arr)
# Out:
# (3, 5)
# 3
# [[ 1  2  3  4  5]
#  [ 2  3  4  5  6]
#  [12 23 34 45 34]]

# %%
a = np.array([1,2,3,4])
b = np.array([4,5,6,7])
c = np.dot(a,b)
np.linalg.norm(a)
# Out:
# np.float64(5.477225575051661)
